# %%
from langchain_text_splitters import CharacterTextSplitter

# %%
text = """
By building a persistent, LLM-maintained record of his projects,
Karpathy is solving the core frustration of "stateless" AI development:
the dreaded context-limit reset.
As anyone who has vibe coded can attest, hitting a usage limit or ending
a session often feels like a lobotomy for your project. You’re forced to
spend valuable tokens (and time) reconstructing context for the AI, hoping
it "remembers" the architectural nuances you just established. 
Karpathy proposes something simpler and more loosely, messily elegant than 
the typical enterprise solution of a vector database and RAG pipeline. 
Instead, he outlines a system where the LLM itself acts as a full-time
"research librarian"—actively compiling, linting, and interlinking Markdown
(.md) files, the most LLM-friendly and compact data format.
"""

# %%
splitter = CharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap=0,
    separator=''
)

# %%
result = splitter.split_text(text)

# %%
print(result)
# Out:
# ['By building a persistent, LLM-maintained record of his projects,\nKarpathy is solving the core frust', 'ration of "stateless" AI development:\nthe dreaded context-limit reset.\nAs anyone who has vibe coded', 'can attest, hitting a usage limit or ending\na session often feels like a lobotomy for your project.', 'You’re forced to\nspend valuable tokens (and time) reconstructing context for the AI, hoping\nit "reme', 'mbers" the architectural nuances you just established. \nKarpathy proposes something simpler and more', 'loosely, messily elegant than \nthe typical enterprise solution of a vector database and RAG pipelin', 'e. \nInstead, he outlines a system where the LLM itself acts as a full-time\n"research librarian"—acti', 'vely compiling, linting, and interlinking Markdown\n(.md) files, the most LLM-friendly and compact da', 'ta format.']

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../../data/windows_system_detailed_report.pdf")

# %%
pdf = loader.load()

# %%
result = splitter.split_documents(pdf)
print(result[0].page_content)
# Out:
# Windows 11 System Configuration Report
# User Profile Information
# - Account Name: Admin
# - Account Type
