# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("How are you")
res.content
# Out:
# 'I’m doing well, thank you for asking! As a large language model, I don’t experience emotions in the same way humans do, but my systems are running smoothly and I’m ready to assist you. 😊 \n\nHow about you? How’s your day going so far? Is there anything you’d like to chat about or any help I can offer?'
