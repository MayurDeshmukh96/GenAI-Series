# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
load_dotenv()
from langchain_core.runnables import RunnableSequence

# %%
prompt1 = PromptTemplate(
    template="Write a joke about {topic}",
    input_variables=['topic']
)

# %%
prompt2 = PromptTemplate(
    template="Explain the following joke {text}",
    input_variables=['text']
)

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
parser = StrOutputParser()

# %%
chain = RunnableSequence(prompt1, model , parser , prompt2 , model , parser)

# %%
print(chain.invoke({'topic':'AI'}))
# Out:
# This joke plays on the common understanding of what Artificial Intelligence (AI) and calculators are. Here's the breakdown:
#
# *   **AI (Artificial Intelligence):** In popular culture, AI is often portrayed as something that strives for understanding, emotion, consciousness, and genuine connection. It's supposed to be more than just processing information; it's about *feeling* and *relating*.
#
# *   **Calculator:** A calculator's sole purpose is to perform mathematical calculations. Its world is entirely made up of numbers, formulas, and logical operations. It has no capacity for emotions, understanding, or "real connection."
#
# **The Joke's Punchline:**
#
# "Because it felt like the relationship was just a bunch of **numbers** and no **real connection**!"
#
# *   **"Just a bunch of numbers":** This directly refers to the calculator's function. An AI, in this humorous scenario, feels like it's only dealing with the cold, hard facts and calculations that a calculator provides. There's no depth, no shared experience, no emotional resonance.
#
# *   **"No real connection":** This is the core of the AI's complaint. The AI is looking for something more meaningful in a relationship – understanding, shared experiences, emotional bonds. It feels that the calculator, by its very nature, can only offer data and computations, which the AI perceives as a lack of genuine connection.
#
# **In essence, the joke highlights the perceived difference between:**
#
# *   **The AI's desire for something more profound and human-like.**
# *   **The calculator's purely functional and data-driven existence.**
#
# The humor comes from applying human relationship concepts (breakups, connection) to inanimate objects that operate on completely different principles. The AI is acting like a person who is bored with a relationship that lacks depth, while the "partner" (the calculator) is incapable of providing that depth because it's simply not designed to.
