# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
history = []
while True:
    query = input("User:")

    if query.lower() in ['exit', 'buy', 'quit']:
        break

    history.append({"role":"user", "content":query})
    print("User:",query)

    res = llm.invoke(history)
    history.append({"role":"ai", "content":res.content})

    print("AI:",res.content,"\n")
# Out:
# User: who is shahruk khan
# AI: Shah Rukh Khan, often referred to as **"King Khan," "Baadshah,"** or simply **"SRK,"** is one of the most iconic, successful, and globally recognized Indian actors. He is a prominent figure in the Hindi film industry, commonly known as Bollywood.
#
# Here are some key facts about him:
#
# 1.  **Actor:** He began his career in television serials in the late 1980s before making his film debut in 1992. He quickly rose to prominence and became known for his romantic leading roles, though he has also excelled in a diverse range of genres, including action, drama, comedy, and even negative roles.
# 2.  **Filmography:** His career spans over three decades, with hundreds of films to his credit. Some of his most celebrated and highest-grossing films include *Dilwale Dulhania Le Jayenge*, *Kuch Kuch Hota Hai*, *Kabhi Khushi Kabhie Gham...*, *Devdas*, *My Name Is Khan*, *Chak De! India*, *Chennai Express*, *Pathaan*, and *Jawan*.
# 3.  **Producer & Entrepreneur:** Beyond acting, SRK is also a successful film producer. He co-owns the production company **Red Chillies Entertainment** (along with his wife Gauri Khan). He is also a co-owner of the Indian Premier League (IPL) cricket team **Kolkata Knight Riders (KKR)**.
# 4.  **Global Icon:** Shah Rukh Khan has an immense global fan base, making him one of the most recognizable and influential personalities from India worldwide. He is often cited as one of the wealthiest actors in the world.
# 5.  **Awards & Recognition:** His contributions to Indian cinema have earned him numerous accolades, including 14 Filmfare Awards, the Padma Shri by the Government of India, and the Ordre des Arts et des Lettres and Legion of Honour by the French government.
# 6.  **Personality:** He is celebrated not just for his acting prowess but also for his charm, wit, intelligence, and philanthropic efforts.
#
# In essence, Shah Rukh Khan is a global superstar, a cultural icon, and a true legend of Indian cinema.
#
# User: what is age of his
# AI: Shah Rukh Khan was born on **November 2, 1965**.
#
# As of June 2024, he is **58 years old**. He will turn 59 in November 2024.
#
# User: okk bye
# AI: You're welcome! Have a great day!
#
# User: bye
# AI: Goodbye!
