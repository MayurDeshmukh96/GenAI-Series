# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel,RunnableSequence
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template="Generate a tweet post about {topic}",
    input_variables=['topic']
)

# %%
prompt2 = PromptTemplate(
    template="Generate a linkedin post about {topic}",
    input_variables=['topic']
)

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
parser = StrOutputParser()

# %%
parallel_chain = RunnableParallel({
    'tweet':RunnableSequence(prompt1,model,parser),
    'linkedin':RunnableSequence(prompt2,model,parser)
})

# %%
result = parallel_chain.invoke({'topic':'AI'})
print(result['linkedin'])
print(result['tweet'])
# Out:
# Here are a few LinkedIn post options about AI, ranging in tone and focus. Choose the one that best fits your audience and your personal brand!
#
# ---
#
# **Option 1: Thought-Provoking & Forward-Looking**
#
# **Headline:** The AI Revolution: Are We Ready for What's Next?
#
# **Body:** We're living through an unprecedented era of technological advancement, with Artificial Intelligence at the forefront. From automating mundane tasks to unlocking groundbreaking scientific discoveries, AI's potential is vast and rapidly unfolding.
#
# But with immense power comes immense responsibility. As AI becomes more integrated into our daily lives and professional workflows, critical questions arise about ethics, job displacement, and ensuring equitable access.
#
# What are your thoughts on the biggest challenges and opportunities AI presents for the future of work and society? Let's discuss! 👇
#
# #AI #ArtificialIntelligence #FutureOfWork #Innovation #Technology #DigitalTransformation #Ethics
#
# ---
#
# **Option 2: Practical & Focus on Business Impact**
#
# **Headline:** Unlocking Business Value with AI: Beyond the Hype
#
# **Body:** While the buzz around AI can be overwhelming, its real power lies in its ability to drive tangible business outcomes. I'm seeing incredible examples of companies leveraging AI for:
#
# ✅ Enhanced customer experiences through personalized recommendations and support.
# ✅ Increased operational efficiency via intelligent automation.
# ✅ Deeper insights from data analysis for better decision-making.
# ✅ Accelerated product development and innovation.
#
# Are you exploring AI solutions in your organization? What's been your experience or biggest win? Share your insights!
#
# #AIinBusiness #BusinessStrategy #DigitalTransformation #DataAnalytics #Automation #CustomerExperience #Innovation
#
# ---
#
# **Option 3: Curiosity-Driven & Engaging Question**
#
# **Headline:** AI: Friend, Foe, or Future Colleague?
#
# **Body:** The conversation around Artificial Intelligence is everywhere. It's a topic that sparks both excitement and apprehension.
#
# Is AI poised to be a powerful tool that augments our capabilities, a disruptive force that reshapes industries, or something else entirely?
#
# I'm curious to hear your perspectives. What's one thing about AI that fascinates or concerns you the most?
#
# #AI #ArtificialIntelligence #Future #TechnologyTrends #Innovation #Discussion #CareerDevelopment
#
# ---
#
# **Option 4: Personal Anecdote & Learning Focus**
#
# **Headline:** My Journey into Understanding AI's Impact
#
# **Body:** Lately, I've been diving deeper into the world of Artificial Intelligence, and the more I learn, the more I'm amazed by its transformative potential. From understanding natural language processing to exploring machine learning algorithms, it's a constant learning curve!
#
# What resources (articles, courses, podcasts) have you found most valuable for understanding AI? I'm always looking to expand my knowledge.
#
# #AI #Learning #PersonalDevelopment #Technology #MachineLearning #DataScience #ContinuousLearning
#
# ---
#
# **Remember to:**
#
# *   **Add a relevant image or video:** This can significantly boost engagement. Consider a futuristic graphic, a team collaborating, or an infographic.
# *   **Tag relevant people or companies:** If you're referencing specific work or individuals.
# *   **Engage with comments:** Respond to people who comment on your post to keep the conversation going.
# *   **Tailor it to your audience:** Think about what your connections on LinkedIn care about most.
#
# Choose the option that resonates most with you and happy posting!
