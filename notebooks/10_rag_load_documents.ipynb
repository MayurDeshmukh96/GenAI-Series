# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Text Reader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/sql_history.txt", encoding="utf-8")
texts = loader.load()
print(texts)
len(texts)
# Out:
# [Document(metadata={'source': '../data/sql_history.txt'}, page_content='Structured Query Language (SQL) is a standardized programming language used to manage and manipulate relational databases. Its history begins in 1970 when computer scientist Edgar F. Codd, working at IBM, introduced the concept of the relational database in his groundbreaking research paper titled “A Relational Model of Data for Large Shared Data Banks.” In this paper, Codd proposed organizing data into tables consisting of rows and columns, which could be linked through relationships rather than using the hierarchical or network database models that were common at the time. To implement this idea, IBM researchers Donald D. Chamberlin and Raymond F. Boyce developed a query language in the mid-1970s called SEQUEL (Structured English Query Language), designed to allow users to retrieve and manipulate data using simple English-like commands. Due to trademark issues, the name was shortened to SQL, though it is often 
# ...

# %% [markdown]
# ### PDF loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/JS1 ClassNotes.pdf")
docs = loader.load()
len(docs)
# Out:
# 10

# %%
onedocs = docs[0]
onedocs.page_content
# Out:
# 'What is JavaScript?\nuse console in any browser or just open one of your projects and use thatthe code is not permanent, we can use the up & down arrow to bring back old code\nA\np\nn\na\n \nC\no\nl\nl\ne\ng\ne\nJS is a programming language. We use it to give instructions to the computer.\nOutputInput (code) Computer'

# %% [markdown]
# ### CSV file loader

# %%
from langchain_community.document_loaders import CSVLoader
csvloader = CSVLoader("../data/customer_data_200_rows_updated.csv")
csv_docs = csvloader.load()
len(csv_docs)
csv_docs[:5]
# Out:
# [Document(metadata={'source': '../data/customer_data_200_rows_updated.csv', 'row': 0}, page_content='age: 40\ngender: Female\nreview: good\neducation: school\npurchased: No'),
#  Document(metadata={'source': '../data/customer_data_200_rows_updated.csv', 'row': 1}, page_content='age: 40\ngender: Male\nreview: avg\neducation: PG\npurchased: No'),
#  Document(metadata={'source': '../data/customer_data_200_rows_updated.csv', 'row': 2}, page_content='age: 45\ngender: Male\nreview: poor\neducation: PG\npurchased: No'),
#  Document(metadata={'source': '../data/customer_data_200_rows_updated.csv', 'row': 3}, page_content='age: 48\ngender: Male\nreview: avg\neducation: school\npurchased: No'),
#  Document(metadata={'source': '../data/customer_data_200_rows_updated.csv', 'row': 4}, page_content='age: 47\ngender: Male\nreview: avg\neducation: PG\npurchased: No')]

# %% [markdown]
# ### WEB page loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path="https://unichronic.com/")
docs = loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
docs[0].page_content
# Out:
# '\n\n\n\n\n\n\n\nIT Services Company India, Cloud, IOT, Chatbots, Mobile & Web Development\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nAbout Us\n\n\nOur Services\n\n\n\n\n\t\t\t\t\t\t\t\t\tCloud Computing\n\n\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tStaff Augmentation\n\n\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tInternet of Things\n\n\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tMobile Engineering\n\n\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tWeb Development\n\n\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\tData Analytics\n\n\t\t\t\t\t\t\t\t\n\n\n\n\nOur Work\n\n\nSuccess Stories\n\n\nGovernment\n\n - New India Conclave\n - New India Awards\n\n\n\nRetail\n\n - CAGAAY\n\n\n\nMedia & Entertainment\n\n - Musicrony\n\n\n\n\n\n\nProducts\n\n\n\n\n\t\t\t\t\t\t\t\t\t\tUniVotes\n\n\t\t\t\t\t\t\t\t\t\n\n\n\n\n\t\t\t\t\t\t\t\t\t\tUniLearning\n\n\t\t\t\t\t\t\t\t\t\n\n\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCloud
# ...

# %% [markdown]
# ### Wikipedia

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query="Who is harshvardhan rane ?",load_max_docs=2)
docs = loader.load()

# %%
docs[0].page_content
# Out:
# 'Harshvardhan Rane (born 16 December 1983) is an Indian actor, who primarily works in Hindi and Telugu films. Rane made his screen debut with the Telugu film Thakita Thakita (2010), and made his Hindi film debut with Sanam Teri Kasam (2016), for which he received the Stardust Award for Superstar of Tomorrow – Male nomination.\nRane started his career with a small stint on television, in Left Right Left  (2007–2008). He then appeared in successful Telugu films including Naa Ishtam (2012), Avunu (2012), Prema Ishq Kaadhal (2013), Anaamika (2014). After venturing into Hindi films, Rane has received praise for his portrayal of a gangster in Taish (2020), an adventure lover in Haseen Dillruba (2021) and a politician in the sleeper hit Ek Deewane Ki Deewaniyat (2025).\n\n\n== Early life ==\nRane was born on 16 December 1983 in Rajamahendravaram, Andhra State, India to a Telugu mother and a Marathi father. His father Vivek Rane was a doctor in his hometown Gwalior, Madhya Pradesh. He was br
# ...
