# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
# prompts = [
#     {"role":"system", "content":"You are a javascript developer."},
#     {"role":"user", "content":"Difference between map and filter"},
# ]

# res = llm.invoke(prompts)
# print(res.content)

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a translator and translate input in {language}"),
    ("user", "{query}"),
])

final_prompts = prompt_template.format_messages(language="hindi", query="I love you!!!!")
final_prompts
# Out:
# [SystemMessage(content='You are a translator and translate input in hindi', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='I love you!!!!', additional_kwargs={}, response_metadata={})]

# %%
# res = llm.invoke(final_prompts)
# print(res.content)

# %%
# prompt_template.invoke({"language":"hindi","query":"I love you!!!!"})
# res = llm.invoke(prompt_template.invoke({"language":"hindi","query":"I love you!!!!"}))
# res.content

# %%
# chain = prompt_template | llm 
# res = chain.invoke({"language":"hindi","query":"I love you!!!!"})
# res.content

# %%
from langchain_core.output_parsers import StrOutputParser
out = StrOutputParser()

# %%
# chain = prompt_template | llm | out
# res = chain.invoke({"language":"hindi","query":"I love you!!!!"})
# res
# Out:
# 'मैं तुमसे प्यार करता हूँ!!!!'

# %%
def transform_case(result:str):
    return result.upper()

# %%
chain = prompt_template | llm | out | transform_case
res = chain.invoke({"language":"hinglish","query":"I love you!!!!"})
res
# Out:
# 'MAIN TUMSE PYAAR KARTA HOON!'
