# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = PromptTemplate(
    template="Give me 5 interacting facts about {topic}",
    input_variables=['topic']
)

# %%
model = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

# %%
result = chain.invoke({'topic':'Cricket'})
print(result)
# Out:
# Here are 5 interacting facts about cricket, meaning each fact builds upon or relates to the others:
#
# 1.  **The concept of "wickets" is central to cricket, and their destruction is the primary way a batsman is dismissed.** This involves a bowler throwing a ball towards a set of three stumps topped with two bails, aiming to dislodge them.
#
# 2.  **A wicket-keeper stands behind the batsman's wicket to catch any balls missed by the batsman, often reacting to the bowler's delivery and the batsman's shot.** This role is crucial for preventing runs and for effecting stumpings, which is another mode of dismissal where the wicket-keeper uses the ball to break the stumps while the batsman is out of their crease.
#
# 3.  **The number of wickets taken by a bowling side directly influences the number of overs a batting side has to score runs.** In most forms of cricket, a team's innings ends when they lose 10 wickets, regardless of how many overs have been bowled. This creates a dynamic where batsmen must protect their wickets while also trying to score.
#
# 4.  **The performance of the wicket-keeper is often directly linked to the effectiveness of the bowlers and the strategy of the fielding captain.** A good wicket-keeper can save crucial runs, take spectacular catches that dismiss key batsmen, and create opportunities for stumpings, all of which contribute to the bowlers' success and the team's overall goal of taking wickets.
#
# 5.  **The strategic interplay between batsmen trying to score runs and bowlers trying to take wickets, with the wicket-keeper playing a supporting role, dictates the flow of the game and the ultimate outcome.** The constant battle to either protect wickets or dismantle them, combined with the scoring efforts of the batsmen, is the fundamental engine of a cricket match.
