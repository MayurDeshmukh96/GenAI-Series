# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt1 = PromptTemplate(
    template="Give me very detailed description about {topic}",
    input_variables="topic"
)

# %%
prompt2 = PromptTemplate(
    template="Give me 5 points summary about {text}",
    input_variables="text"
)

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
parser = StrOutputParser()

# %%
chain = prompt1 | model | parser | prompt2 | model | parser

# %%
result = chain.invoke({'topic':'ML'})
print(result)
# Out:
# Here's a 5-point summary of the provided text on Machine Learning:
#
# 1.  **Core Principle & Components:** Machine Learning (ML) enables systems to learn from data without explicit programming, improving performance through experience. Key components include Data (fuel), Algorithms/Models (engine), Features (measurable characteristics), Training (learning process), Prediction/Inference (output), and Evaluation (performance assessment).
#
# 2.  **Diverse Learning Approaches:** ML is broadly categorized into four main types:
#     *   **Supervised Learning:** Learns from labeled data for tasks like classification (categorizing) and regression (predicting continuous values).
#     *   **Unsupervised Learning:** Discovers patterns in unlabeled data through clustering (grouping) and dimensionality reduction (simplifying features).
#     *   **Semi-Supervised Learning:** Combines small amounts of labeled data with large amounts of unlabeled data.
#     *   **Reinforcement Learning:** An agent learns through trial and error in an environment, aiming to maximize rewards.
#
# 3.  **Deep Learning as a Subset:** Deep Learning (DL) is a powerful ML subfield that uses multi-layered neural networks to learn hierarchical representations of data, often achieving state-of-the-art results in areas like image and natural language processing, but requiring significant data and computational power.
#
# 4.  **ML Workflow & Key Challenges:** A typical ML project involves problem definition, data collection/preprocessing, model selection/training, evaluation, and deployment. Key challenges include overfitting/underfitting, managing bias/variance, feature engineering, ensuring interpretability (XAI), data privacy, ethical considerations, and computational resource demands.
#
# 5.  **Widespread Applications & Future Trends:** ML is transforming numerous industries like healthcare, finance, e-commerce, and transportation with applications ranging from disease diagnosis and fraud detection to recommendation systems and autonomous vehicles. The future emphasizes Explainable AI, Federated Learning, AutoML, advancements in Generative AI, and a strong focus on ethical and responsible AI development.
